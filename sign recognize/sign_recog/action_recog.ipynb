# %%
! pip install tensorflow opencv-python mediapipe scikit-learn matplotlib tensorflowjs

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
# Out:
# WARNING:tensorflow:From c:\Users\shubh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR-CONVERSION BGR-to-RGB
    image.flags.writeable = False                  # Convert image to not-writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Convert image to writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR-COVERSION RGB-to-BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
draw_landmarks(frame,results)

# %%
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %% [markdown]
# <3> Extract Key Point Values

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %% [markdown]
# ########setting up folders

# %%
DATA_PATH=os.path.join('MP_Data')
actions=np.array(['hello','thanks','sorry','bye'])
no_sequences=20
sequence_length=20
start_folder=20

# %%
#for action in actions:
 #   for sequence in range(no_sequences):
  #      try:
   #         os.makedirs(os.path.join(DATA_PATH,action,str(sequence)))
    #    except:
     #       pass

# %%
#cap=cv2.VideoCapture(0)
#set mediapipe model
#with mp_holistic.Holistic(min_detection_confidence=0.5,min_tracking_confidence=0.5) as holistic:
 #   for action in actions:
  #      for sequence in range(no_sequences):
   #         for frame_num in range(sequence_length):
    #            ret,frame=cap.read()
     #   
      #          #make detections
       #         image,results=mediapipe_detection(frame,holistic)
        #        
         #       #draw landmarksq
               # draw_styled_landmarks(image,results)
                
               # if frame_num==0:
               #     cv2.putText(image,'STARTING COLLECTION',(120,200),
                #                cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),4,cv2.LINE_AA)
               #     cv2.putText(image,'collecting frames for {} Video Number {}'.format(action,sequence),(15,12),
                #                cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),4,cv2.LINE_AA)
               #     cv2.imshow('openCV Feed',image)
              #      cv2.waitKey(2000)
             #   
            #    else:
           #         cv2.putText(image,'collecting frames for {} Video Number {}'.format(action,sequence),(15,12),
          #                      cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),4,cv2.LINE_AA)
         #           cv2.imshow('openCV Feed',image)
        #            
       #         keypoints=extract_keypoints(results)
      #          npy_path=os.path.join(DATA_PATH,action,str(sequence),str(frame_num)) 
     #           np.save(npy_path,keypoints)   
    #            
   #             
  #              if cv2.waitKey(10) & 0xFF == ord('q'):#destroy/break out gracefully
  #                  break
 #  cap.release()
#    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ####preprocess data and create labels and features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical # type: ignore

# %%
label_map={label:num for num,label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'sorry': 2, 'bye': 3}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
X=np.array(sequences)

# %%
y=to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %% [markdown]
# Build and train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential # type: ignore
from tensorflow.keras.layers import LSTM,Dense # type: ignore
from tensorflow.keras.callbacks import TensorBoard # type: ignore

# %%
log_dir=os.path.join('Logs')
tb_callback=TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(20,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# WARNING:tensorflow:From c:\Users\shubh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\shubh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train, y_train, epochs=1000, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\shubh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\shubh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 9s 235ms/step - loss: 1.4151 - categorical_accuracy: 0.2632
# Epoch 2/200
# 3/3 [==============================] - 0s 159ms/step - loss: 1.5553 - categorical_accuracy: 0.3158
# Epoch 3/200
# 3/3 [==============================] - 0s 157ms/step - loss: 1.9077 - categorical_accuracy: 0.2895
# Epoch 4/200
# 3/3 [==============================] - 0s 126ms/step - loss: 1.4453 - categorical_accuracy: 0.2368
# Epoch 5/200
# 3/3 [==============================] - 0s 133ms/step - loss: 1.4113 - categorical_accuracy: 0.3158
# Epoch 6/200
# 3/3 [==============================] - 0s 116ms/step - loss: 1.3822 - categorical_accuracy: 0.2632
# Epoch 7/200
# 3/3 [==============================] - 0s 117ms/step - loss: 1.4323 - categorical_accuracy: 0.2895
# Epoch 8/200
# 3/3 [==============================] - 0s 125ms/step - loss: 1.3570 - categorical_accuracy: 0.2632
# Epoch 9/200
# 3/3 [==============================] - 0s 139ms/step - loss: 1.7418 - categorical_accuracy: 0.2500
# Epoch 10/200
# 3/3 [==============================] - 0s 128ms/step - loss: 1.3779 - categorical_accuracy: 0.2895
# Epoch 11/200
# 3/3 [==============================] - 0s 103ms/step - loss: 1.4178 - categorical_accuracy: 0.2632
# Epoch 12/200
# 3/3 [==============================] - 0s 113ms/step - loss: 1.3705 - categorical_accuracy: 0.2763
# Epoch 13/200
# 3/3 [==============================] - 0s 105ms/step - loss: 1.3864 - categorical_accuracy: 0.3553
# Epoch 14/200
# 3/3 [==============================] - 0s 107ms/step - loss: 1.3839 - categorical_accuracy: 0.3158
# Epoch 15/200
# 3/3 [==============================] - 0s 115ms/step - loss: 1.3831 - categorical_accuracy: 0.3289
# Epoch 16/200
# 3/3 [==============================] - 0s 109ms/step - loss: 1.3792 - categorical_accuracy: 0.3553
# Epoch 17/200
# 3/3 [==============================] - 0s 109ms/step - loss: 1.3769 - categorical_accuracy: 0.2500
# Epoch 18/200
# 3/3 [==============================] - 0s 143ms/step - loss: 1.3710 - categorical_accuracy: 0.2500
# Epoch 19/200
# 3/3 [==============================] - 0s 134ms/step - loss: 1.3675 - categorical_accuracy: 0.2500
# Epoch 20/200
# 3/3 [==============================] - 1s 199ms/step - loss: 1.3582 - categorical_accuracy: 0.2763
# Epoch 21/200
# 3/3 [==============================] - 0s 140ms/step - loss: 1.3447 - categorical_accuracy: 0.3553
# Epoch 22/200
# 3/3 [==============================] - 0s 184ms/step - loss: 1.3264 - categorical_accuracy: 0.4079
# Epoch 23/200
# 3/3 [==============================] - 0s 157ms/step - loss: 1.2843 - categorical_accuracy: 0.4737
# Epoch 24/200
# 3/3 [==============================] - 0s 134ms/step - loss: 1.2596 - categorical_accuracy: 0.3947
# Epoch 25/200
# 3/3 [==============================] - 0s 144ms/step - loss: 1.3321 - categorical_accuracy: 0.3421
# Epoch 26/200
# 3/3 [==============================] - 0s 151ms/step - loss: 1.4318 - categorical_accuracy: 0.2632
# Epoch 27/200
# 3/3 [==============================] - 0s 162ms/step - loss: 1.3959 - categorical_accuracy: 0.2763
# Epoch 28/200
# 3/3 [==============================] - 0s 155ms/step - loss: 1.3526 - categorical_accuracy: 0.3158
# Epoch 29/200
# 3/3 [==============================] - 0s 129ms/step - loss: 1.3224 - categorical_accuracy: 0.4342
# Epoch 30/200
# 3/3 [==============================] - 0s 119ms/step - loss: 1.2953 - categorical_accuracy: 0.3553
# Epoch 31/200
# 3/3 [==============================] - 0s 154ms/step - loss: 1.7237 - categorical_accuracy: 0.2763
# Epoch 32/200
# 3/3 [==============================] - 0s 106ms/step - loss: 1.3865 - categorical_accuracy: 0.2500
# Epoch 33/200
# 3/3 [==============================] - 0s 153ms/step - loss: 1.3800 - categorical_accuracy: 0.3421
# Epoch 34/200
# 3/3 [==============================] - 0s 134ms/step - loss: 1.3140 - categorical_accuracy: 0.2500
# Epoch 35/200
# 3/3 [==============================] - 0s 129ms/step - loss: 1.2701 - categorical_accuracy: 0.3421
# Epoch 36/200
# 3/3 [==============================] - 0s 134ms/step - loss: 1.2148 - categorical_accuracy: 0.5000
# Epoch 37/200
# 3/3 [==============================] - 0s 109ms/step - loss: 1.1725 - categorical_accuracy: 0.4868
# Epoch 38/200
# 3/3 [==============================] - 0s 185ms/step - loss: 1.2506 - categorical_accuracy: 0.4079
# Epoch 39/200
# 3/3 [==============================] - 0s 119ms/step - loss: 1.5041 - categorical_accuracy: 0.2895
# Epoch 40/200
# 3/3 [==============================] - 0s 131ms/step - loss: 1.4668 - categorical_accuracy: 0.2632
# Epoch 41/200
# 3/3 [==============================] - 0s 123ms/step - loss: 1.4049 - categorical_accuracy: 0.2632
# Epoch 42/200
# 3/3 [==============================] - 0s 103ms/step - loss: 1.4079 - categorical_accuracy: 0.2632
# Epoch 43/200
# 3/3 [==============================] - 0s 119ms/step - loss: 1.3095 - categorical_accuracy: 0.3553
# Epoch 44/200
# 3/3 [==============================] - 0s 106ms/step - loss: 1.2656 - categorical_accuracy: 0.3684
# Epoch 45/200
# 3/3 [==============================] - 0s 124ms/step - loss: 1.0611 - categorical_accuracy: 0.4868
# Epoch 46/200
# 3/3 [==============================] - 0s 127ms/step - loss: 1
200
# 3/3 [==============================] - 0s 148ms/step - loss: 0.7969 - categorical_accuracy: 0.6711
# Epoch 135/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.9519 - categorical_accuracy: 0.5000
# Epoch 136/200
# 3/3 [==============================] - 0s 140ms/step - loss: 0.9229 - categorical_accuracy: 0.4605
# Epoch 137/200
# 3/3 [==============================] - 0s 136ms/step - loss: 1.0941 - categorical_accuracy: 0.4474
# Epoch 138/200
# 3/3 [==============================] - 0s 143ms/step - loss: 0.8528 - categorical_accuracy: 0.6053
# Epoch 139/200
# 3/3 [==============================] - 0s 142ms/step - loss: 0.8103 - categorical_accuracy: 0.5526
# Epoch 140/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.7119 - categorical_accuracy: 0.7105
# Epoch 141/200
# 3/3 [==============================] - 0s 139ms/step - loss: 0.6791 - categorical_accuracy: 0.7368
# Epoch 142/200
# 3/3 [==============================] - 0s 141ms/step - loss: 0.6268 - categorical_accuracy: 0.8158
# Epoch 143/200
# 3/3 [==============================] - 0s 132ms/step - loss: 0.7903 - categorical_accuracy: 0.6184
# Epoch 144/200
# 3/3 [==============================] - 0s 148ms/step - loss: 0.8227 - categorical_accuracy: 0.6711
# Epoch 145/200
# 3/3 [==============================] - 0s 123ms/step - loss: 1.1947 - categorical_accuracy: 0.5000
# Epoch 146/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.8172 - categorical_accuracy: 0.6316
# Epoch 147/200
# 3/3 [==============================] - 0s 147ms/step - loss: 0.7441 - categorical_accuracy: 0.6711
# Epoch 148/200
# 3/3 [==============================] - 0s 148ms/step - loss: 0.7481 - categorical_accuracy: 0.6184
# Epoch 149/200
# 3/3 [==============================] - 0s 123ms/step - loss: 0.6446 - categorical_accuracy: 0.7895
# Epoch 150/200
# 3/3 [==============================] - 0s 143ms/step - loss: 0.6082 - categorical_accuracy: 0.7763
# Epoch 151/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.5587 - categorical_accuracy: 0.8289
# Epoch 152/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.5252 - categorical_accuracy: 0.8289
# Epoch 153/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.4969 - categorical_accuracy: 0.8158
# Epoch 154/200
# 3/3 [==============================] - 0s 152ms/step - loss: 0.5311 - categorical_accuracy: 0.7763
# Epoch 155/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.5336 - categorical_accuracy: 0.7632
# Epoch 156/200
# 3/3 [==============================] - 0s 147ms/step - loss: 0.8070 - categorical_accuracy: 0.6316
# Epoch 157/200
# 3/3 [==============================] - 0s 140ms/step - loss: 0.5561 - categorical_accuracy: 0.7632
# Epoch 158/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.6918 - categorical_accuracy: 0.6842
# Epoch 159/200
# 3/3 [==============================] - 0s 148ms/step - loss: 0.8101 - categorical_accuracy: 0.6711
# Epoch 160/200
# 3/3 [==============================] - 0s 133ms/step - loss: 0.8002 - categorical_accuracy: 0.6579
# Epoch 161/200
# 3/3 [==============================] - 0s 151ms/step - loss: 0.5283 - categorical_accuracy: 0.8289
# Epoch 162/200
# 3/3 [==============================] - 0s 133ms/step - loss: 0.5587 - categorical_accuracy: 0.7368
# Epoch 163/200
# 3/3 [==============================] - 0s 139ms/step - loss: 0.5140 - categorical_accuracy: 0.7763
# Epoch 164/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.5632 - categorical_accuracy: 0.8289
# Epoch 165/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.5421 - categorical_accuracy: 0.7368
# Epoch 166/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.4426 - categorical_accuracy: 0.8816
# Epoch 167/200
# 3/3 [==============================] - 0s 116ms/step - loss: 0.5661 - categorical_accuracy: 0.7763
# Epoch 168/200
# 3/3 [==============================] - 0s 138ms/step - loss: 0.6903 - categorical_accuracy: 0.6974
# Epoch 169/200
# 3/3 [==============================] - 0s 137ms/step - loss: 0.8173 - categorical_accuracy: 0.5921
# Epoch 170/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.8650 - categorical_accuracy: 0.6447
# Epoch 171/200
# 3/3 [==============================] - 0s 104ms/step - loss: 0.9803 - categorical_accuracy: 0.6053
# Epoch 172/200
# 3/3 [==============================] - 0s 107ms/step - loss: 0.7935 - categorical_accuracy: 0.6579
# Epoch 173/200
# 3/3 [==============================] - 0s 128ms/step - loss: 0.6385 - categorical_accuracy: 0.6842
# Epoch 174/200
# 3/3 [==============================] - 0s 118ms/step - loss: 0.6314 - categorical_accuracy: 0.7105
# Epoch 175/200
# 3/3 [==============================] - 0s 133ms/step - loss: 0.6291 - categorical_accuracy: 0.7237
# Epoch 176/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.5314 - categorical_accuracy: 0.7500
# Epoch 177/200
# 3/3 [==============================] - 0s 133ms/step - loss: 0.4759 - categorical_accuracy: 0.8816
# Epoch 178/200
# 3/3 [==============================] - 0s 166ms/step - loss: 0.4382 - categorical_accuracy: 0.8553
# Epoch 179/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.4297 - categorical_accuracy: 0.8421
# Epoch 180/200
# 3/3 [==============================] - 0s 117ms/step - loss: 0.4799 - categorical_accuracy: 0.7895
# Epoch 181/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.4432 - categorical_accuracy: 0.8684
# Epoch 182/200
# 3/3 [==============================] - 0s 127ms/step - loss: 0.4501 - categorical_accuracy: 0.7895
# Epoch 183/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.5567 - categorical_accuracy: 0.7895
# Epoch 184/200
# 3/3 [==============================] - 0s 101ms/step - loss: 0.6072 - categorical_accuracy: 0.7105
# Epoch 185/200
# 3/3 [==============================] - 0s 138ms/step - loss: 0.3839 - categorical_accuracy: 0.8289
# Epoch 186/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.4291 - categorical_accuracy: 0.8289
# Epoch 187/200
# 3/3 [==============================] - 1s 378ms/step - loss: 0.4492 - categorical_accuracy: 0.8026
# Epoch 188/200
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3782 - categorical_accuracy: 0.8947
# Epoch 189/200
# 3/3 [==============================] - 0s 120ms/step - loss: 0.3470 - categorical_accuracy: 0.8816
# Epoch 190/200
# 3/3 [==============================] - 0s 110ms/step - loss: 0.3719 - categorical_accuracy: 0.8289
# Epoch 191/200
# 3/3 [==============================] - 0s 127ms/step - loss: 1.5019 - categorical_accuracy: 0.3947
# Epoch 192/200
# 3/3 [==============================] - 0s 125ms/step - loss: 0.9836 - categorical_accuracy: 0.6184
# Epoch 193/200
# 3/3 [==============================] - 0s 126ms/step - loss: 0.6508 - categorical_accuracy: 0.7237
# Epoch 194/200
# 3/3 [==============================] - 0s 164ms/step - loss: 0.6043 - categorical_accuracy: 0.7368
# Epoch 195/200
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6587 - categorical_accuracy: 0.6842
# Epoch 196/200
# 3/3 [==============================] - 0s 114ms/step - loss: 0.6792 - categorical_accuracy: 0.6974
# Epoch 197/200
# 3/3 [==============================] - 0s 113ms/step - loss: 0.4964 - categorical_accuracy: 0.8421
# Epoch 198/200
# 3/3 [==============================] - 0s 124ms/step - loss: 0.5811 - categorical_accuracy: 0.7368
# Epoch 199/200
# 3/3 [==============================] - 0s 146ms/step - loss: 0.6262 - categorical_accuracy: 0.6974
# Epoch 200/200
# 3/3 [==============================] - 0s 137ms/step - loss: 0.6010 - categorical_accuracy: 0.7763

# %% [markdown]
# Make predictions

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20, 64)            442112
#
#  lstm_1 (LSTM)               (None, 20, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 596708 (2.28 MB)
# Trainable params: 596708 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
res = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 928ms/step

# %%
actions[np.argmax(res[0])]
# Out:
# 'sorry'

# %%
actions[np.argmax(y_test[0])]
# Out:
# 'sorry'

# %% [markdown]
# save weights

# %%
model.save('./model.h5')
model.save_weights('./model_weights.h5')
# Out:
# c:\Users\shubh\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
del model

# %%
import tensorflow as tf
model = tf.keras.models.load_model('model.h5')

# %%
model.load_weights('model_weights.h5')

# %% [markdown]
# Evaluation using confusion matrix and accuracy

# %%
from sklearn.metrics import  multilabel_confusion_matrix,accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 721ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[2, 2],
#         [0, 0]],
#
#        [[3, 1],
#         [0, 0]],
#
#        [[3, 0],
#         [0, 1]],
#
#        [[1, 0],
#         [3, 0]]], dtype=int64)

# %%
accuracy_score(ytrue,yhat)
# Out:
# 0.25

# %% [markdown]
# Testing

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 1s/step
# hello
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 47
#      44         sentence = sentence[-5:]
#      46     # Viz probabilities
# ---> 47     image = prob_viz(res, actions, image, colors)
#      49 cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#      50 cv2.putText(image, ' '.join(sentence), (3,30),
#      51                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
#
# Cell In[44], line 5, in prob_viz(res, actions, input_frame, colors)
#       3 output_frame = input_frame.copy()
#       4 for num, prob in enumerate(res):
# ----> 5     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6     cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       8 return output_frame
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
